# %%
import gym
import minerl
import matplotlib.pyplot as plt
# Out:
# C:\Users\mateu\AppData\Roaming\Python\Python39\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
#evaluate
#n_runs, number of runs
#n_workers, number of envs

# %%
env = gym.make('MineRLTreechop-v0')

# %%
env.observation_space
# Out:
# Dict(pov:Box(low=0, high=255, shape=(64, 64, 3)))

# %%
# %time obs = env.reset()
# Out:
# CPU times: total: 19.6 s
# Wall time: 2min 1s

# %%
plt.imshow(obs['pov'])

# %%
obs = env.step(env.action_space.sample())
plt.imshow(obs[0]['pov'])
